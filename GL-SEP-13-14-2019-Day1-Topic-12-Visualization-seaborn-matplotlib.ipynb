# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - Barplot
#    - When we want to relate numeric and categorical features
#    - when we want to look at the data at a high level
#
# - distplot
#    - find the distribution for numeric data
#
# - boxplot
#   - find outliers
#   - relate between categorical and numeric
#   - distribution of data
#
# - scatter plot
#   - relate 2 numeric variable
#
# - lmplot
#   - visualize the output of linearmodel
#
# - jointplot
#   - bivariate analysis between 2 numeric features
#   - want the find the distribution of each of those numeric features
#
#  - Heatmap
#   - correlation coefficients between different features in the dataframe
#
#  - stripplot
#   - bivariate analysis between numeric data and non numeric data
#   - allows to understand the concentration of data
#   - distribution of data
#
#  - swarmplot
#    - bivariate analysis between numeric data and non numeric data
#   -  it adds more clarity of distribution of data on categorical axis
#
# - violinplot
#    - bivariate analysis between numeric data and non numeric data

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# ## Plots for Categorical Variables
# - barplot and countplot
#
# These very similar plots allow you to get aggregate data off a categorical feature in your data. **barplot** is a general plot that allows you to aggregate the categorical data based off some function, by default the mean:

# %% [markdown]
# #####  What is a bar plot
# - A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars.
# - Bar plots include 0 in the quantitative axis range, and they are a good choice when 0 is a meaningful value for the quantitative variable, and you want to make comparisons against it.
# - a bar plot shows only the mean (or other estimator) value, but in many cases it may be more informative to show the distribution of values at each level of the categorical variables. In that case, other approaches such as a box or violin plot may be more appropriate.

# %%
### find out which days seem to reward more tips??

sns.set(rc={'figure.figsize':(9,7)})   ### sets the size of the plots


sns.barplot(x='day',y='tip',data=tips,ci=.75)


### insight - sundays seem to be rewarding more tips

# %%
### find out who between men and women order high (high bills)

sns.set(rc={'figure.figsize':(5,4)})   ### sets the size of the plots
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
### find out which days total_bills are higher

sns.set(rc={'figure.figsize':(5,4)})   ### sets the size of the plots
sns.barplot(x='day',y='total_bill',data=tips)

# %%
### find out which days total_bills are higher and who among men and women buy high total bills

sns.set(rc={'figure.figsize':(5,4)})   ### sets the size of the plots
sns.barplot(x='day',y='total_bill',hue='smoker',hue_order=['No','Yes'],color=None,palette='viridis',data=tips)


### Insight, Smokers seem to buy higher total bills on all days except friday. revenue higher with smokers
## what could be the reason why Fridays are less? -

# %%
### find out which days total_bills are higher and who among smokers or non smokers buy high

sns.set(rc={'figure.figsize':(5,4)})   ### sets the size of the plots
sns.barplot(x='day',y='total_bill',hue='sex',color=None,palette='coolwarm',data=tips)


### Insight, Men seem to buy higher total bills on all days.

# %%
### find out which days total_bills are higher and who among smokers or non smokers buy high

sns.set(rc={'figure.figsize':(5,4)})   ### sets the size of the plots
sns.barplot(x='day',y='total_bill',hue='sex',color=None,palette='coolwarm',data=tips)


### Insight, Men seem to buy higher total bills on all days.

# %%
### total bill vs time of the day (breakfast,lunch,dinner) vs sex

sns.set(rc={'figure.figsize':(5,4)})   ### sets the size of the plots
sns.barplot(x='time',y='total_bill',hue='sex',color=None,palette='coolwarm',data=tips)

### men seem to be brining more revenue during both times lunch and dinner

# %%
### total bill vs time  vs smoker
sns.set(rc={'figure.figsize':(5,4)})   ### sets the size of the plots
sns.barplot(x='time',y='total_bill',hue='smoker',color=None,palette='coolwarm',data=tips)

### smokers are high during dinner time
###

# %%
### total bill vs time  vs smoker
sns.set(rc={'figure.figsize':(5,4)})   ### sets the size of the plots
sns.barplot(x='sex',y='total_bill',hue='time',color=None,palette='coolwarm',data=tips)

### smokers are high during dinner time

### dinner time more females than males 
## in the earlier graph,its dinner time more smokers !!
## could be families!!!

# %%
### total bill vs day (breakfast,lunch,dinner) vs time

sns.set(rc={'figure.figsize':(5,4)})   ### sets the size of the plots
sns.barplot(x='day',y='total_bill',hue='time',color=None,palette='coolwarm',data=tips)

### saturdays and sundays are entirely dinner days? 
### opportunity to increase seales for lunch!!!

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
import numpy as np

# %%
### total bill vs Gender
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %% [markdown]
# ### countplot
#
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
### count of men and women
sns.countplot(x='sex',data=tips)

# %%
### count of men and women who are smokers
sns.countplot(x='sex',data=tips,hue='smoker')

# %%
sns.countplot(x='sex',data=tips,hue='day')

# %%
### gender vs time of the day
sns.countplot(x='sex',data=tips,hue='time')

# %% [markdown]
# ## boxplot
#
# - boxplots are used to shown the distribution of categorical data.
# - A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that
#   facilitates comparisons between variables or across levels of a categorical variable.
# - The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
### find the relationship between total_bill vs days
# figure size in inches
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
### find the relationship between total_bill vs days
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 9,6

sns.boxplot(x="sex", y="total_bill", data=tips,palette='rainbow')

# %%
### find the relationship between total_bill vs sex, hue on smoker
sns.set(rc={'figure.figsize':(8,4)})


sns.boxplot(x="sex", y="total_bill",hue='smoker',data=tips,palette='rainbow')

# %%
sns.set(rc={'figure.figsize':(8,4)})

sns.boxplot(x="sex", y="total_bill",hue='day',data=tips,palette='rainbow')

# %%
### find the relationship between total_bill vs sex, hue on smoker
sns.set(rc={'figure.figsize':(9,6)})

sns.boxplot(x="smoker", y="total_bill",hue='time',data=tips,palette='rainbow')

# %%
# Can do entire dataframe with orient='h'
sns.boxplot(data=tips,palette='rainbow',orient='h')

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")

# %% [markdown]
# ### violinplot
# - A violin plot plays a similar role as a box and whisker plot.
#
# - It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared.
#
# - Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation(KDE) of the underlying distribution.

# %% [markdown]
# ## What Is KDE - Kernel Density Estimator
# - Kernel density estimation is a really useful statistical tool .  a technique that let’s you create a smooth curve given a set of data.
#
# - This can be useful if you want to visualize just the “shape” of some data, as a kind of continuous replacement for the discrete histogram.
#
# - It can also be used to generate points that look like they came from a certain dataset - this behavior can power simple simulations, where simulated objects are modeled off of real data.

# %%
sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')

# %% [markdown]
# ## stripplot and swarmplot
# - The stripplot will draw a scatterplot where one variable is categorical.
# - A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show    all observations along with some representation of the underlying distribution.

# %%
sns.stripplot(x="day", y="total_bill", data=tips)

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True)

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1')

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1',split=True)

# %% [markdown]
# ### Swarmplot
# - The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t
#   overlap.
#
# - This gives a better representation of the distribution of values, although it does not scale as well to large numbers of
#   observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
# plot
sns.set_style('ticks')

fig, ax = plt.subplots()

#  set the fig size
fig.set_size_inches(10, 6)

sns.swarmplot(x="day", y="total_bill",hue='sex',data=tips)

#sns.despine()

#fig.savefig('example.png')

# %% [markdown]
# ### Combining Categorical Plots

# %%
rcParams['figure.figsize'] = 9,6
sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')
sns.swarmplot(x="tip", y="day", data=tips,color='black',size=3)

# %% [markdown]
# ## factorplot
#
# factorplot is the most general form of a categorical plot. It can take in a **kind** parameter to adjust the plot type:

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind='box')
# Out:
# C:\Users\anand\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind='bar')
# Out:
# C:\Users\anand\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
### scatter plots

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize=(9,6))
ax = plt.scatter(x="total_bill", y="tip", data=tips)
plt.ylim(0, 20)
plt.xlim(0, 60)
# Out:
# (0, 60)

# %%
### distritbution plot for univariate analysis
### it gives a histogram and a KDE line (Kernel Density Estimation)of the variable being analysed

# figure size in inches
sns.set(rc={'figure.figsize':(9,6)})
sns.distplot(tips['total_bill'],hist=True,rug=True,kde=True)
plt.xticks(range(0, 50, 5))

### to remove kde line , we can use the below command
## sns.distplot(tips['total_bill'],kde=False)

### use bins to get more details of the plot
##  sns.distplot(tips['total_bill'],kds=False, bins=20)
# Out:
# ([<matplotlib.axis.XTick at 0x1d93ecd4f98>,
# ...
#  <a list of 10 Text xticklabel objects>)

# %%
###joint plots

# %%
###jointplot allows to compare two dist plots for bi variate analysis
sns.set(rc={'figure.figsize':(20,6)})

#rcParams['figure.figsize'] = 15,10

sns.jointplot(x='total_bill',y='tip',data=tips)

### scatter plot suggests that as the total bill value goes high, the tip value goes high

# %% [markdown]
#     ### Regression - lmplots
#  - with hue
#  - without hue

# %%
###lmplot allows to compare two dist plots for bi variate analysis
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
###lmplot allows to compare two dist plots for bi variate analysis
sns.lmplot(x='total_bill',y='tip',hue='smoker',data=tips)

# %%
###lmplot allows to compare two dist plots for bi variate analysis
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
###lmplot allows to compare  for bi variate analysis
sns.lmplot(x='total_bill',y='tip',hue='day',data=tips)

# %%
# WE can also specify teh confidence interval to use for the linear fit

sns.lmplot("total_bill","tip",tips,ci=95) # 68% ci

# %%
# Just like before, we can use dictionaries to edit individual parts of the plot

sns.lmplot("total_bill", "tip", tips,
           scatter_kws={"marker": "o", "color": "indianred"},
           line_kws={"linewidth": 1, "color": "blue"});

# %%
# We can also not fit a regression if desired
sns.lmplot("total_bill", "tip",tips,mn)

# %%
# lmplot() also works on discrete variables, such as the percentage of the tip

# Create a new column for tip percentage - what percent of the bill is the tip
tips["tip_pect"]=100*(tips['tip']/tips['total_bill'])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pect
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
#plot tip percentage vs size
sns.lmplot(x="size",y="tip_pect",data=tips,fit_reg=False);

# %%
#plot tip percentage vs size - set jitter to make the data readable
sns.lmplot("size", "tip_pect", tips,x_jitter=.1);

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())

# %%
#plot tip percentage vs size - set jitter to make the data readable

### estimate for the tendency of each bin of size depending on the size of party(people)
sns.lmplot("size", "tip_pect", data=tips,x_estimator=np.mean);

### we have more variance where party size of 1

# %%
### joint plots

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
# Out:
# C:\Users\anand.subramaniam\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:218: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)
# C:\Users\anand.subramaniam\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:218: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %%
### pair plots

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='smoker')

# %%
sns.pairplot(tips,hue='time')

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\anand.subramaniam\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:218: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)
